# %%
import pandas as pd
import numpy as np
import sys
import random

from PIL import Image
from os import listdir
from os.path import isfile, join
from sklearn.neural_network import MLPClassifier

# %%
main_path = 'C:/Users/Rik/Documents/Radboud Universiteit/TFfCA/Data/CFD Version 2.0.3/'
excel_path = main_path + 'CFD 2.0.3 Norming Data and Codebook.xlsx'
pictures_path = main_path + 'CFD 2.0.3 Images/'
cfd = pd.read_excel(excel_path, sheet_name = 0, header = 4, skipRows = 4)
cfd.head()
# Out:
#    Target Race Gender        Age  NumberofRaters  Female_prop  Male_prop  \
# 0  AF-200    A      F  32.571429              28     1.000000   0.000000
# 1  AF-201    A      F  23.666667              27     1.000000   0.000000
# 2  AF-202    A      F  24.448276              29     0.827586   0.172414
# 3  AF-203    A      F  22.758621              29     1.000000   0.000000
# 4  AF-204    A      F  30.137931              29     1.000000   0.000000
#
#    Asian_prop  Black_prop  Latino_prop    ...     EyeShape   EyeSize  \
# 0    1.000000    0.000000     0.000000    ...     0.404651  0.060924
# 1    0.962963    0.000000     0.000000    ...     0.329204  0.041892
# 2    0.310345    0.068966     0.137931    ...     0.357939  0.051586
# 3    0.758621    0.000000     0.068966    ...     0.443200  0.063913
# 4    0.827586    0.000000     0.068966    ...     0.432247  0.053435
#
#    UpperHeadLength  MidfaceLength  ChinLength  ForeheadHeight  \
# ...

# %%
def createTestLabels(trainSet):
    labels = []
    for i in range(0, len(trainSet)):
        labels.append(random.choice([True, False]))
    return labels

# %%
def accessPicture(target):
    testPath = pictures_path + "" + target
    allFilesInPath = [f for f in listdir(testPath) if isfile(join(testPath, f))]
    neutralPic = next((i_path for i_path in allFilesInPath if 'N' in i_path), (""))
    return Image.open(testPath + '/' + neutralPic)

# %%
#Should result in array of 12,596,376 values
def imageToFloats(image):
    red = []
    green = []
    blue = []
    for i in range(0, image.size[0]):
        for j in range(0, image.size[1]):
            r,g,b = image.getpixel((i,j))
            red.append(r)
            green.append(g)
            blue.append(b)
    return red + green + blue

# %%
#Takes an array of picture names as input, returns an array of all pixel values
def buildMLPinput(pictureNames):
    MLPinput = []
    for i in range(0, len(pictureNames)):
        MLPinput.append(imageToFloats(accessPicture(pictureNames[i])))
        print('{} / {} complete.'.format(i+1,len(pictureNames)), end='\r')
        sys.stdout.flush()
    return MLPinput

# %%
exampleTrainSet = cfd.head(3)
etsNames = exampleTrainSet["Target"].tolist()
exampleLabels = createTestLabels(exampleTrainSet)
exampleLabels
# Out:
# [True, True, False]

# %%
exampleTestSet = cfd.loc[5]
# print(exampleTestSet["Target"])
testInput = buildMLPinput([exampleTestSet["Target"]])
testInput
# Out:
# 1 / 1 complete.
# [[255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
# ...

# %%
mlpInput = buildMLPinput(etsNames)
# Out:
# 3 / 3 complete.

# %%
mlpInput
# Out:
# [[255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
#   255,
# ...

# %%
clf = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(1, 634688), random_state=1)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1, 634688), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
clf.fit(mlpInput, exampleLabels)

# %%
clf.predict(testInput)
# Out:
# array([ True])

# %%
# races = cfd.Race.unique()
# genders = cfd.Gender.unique()
# print("Races in dataset:")
# for race in races:
#     print(race, ": ", len(cfd.loc[cfd['Race'] == race]))
# print('='*50)

# print("Genders in dataset:")
# for gender in genders:
#     print(gender, ": ", len(cfd.loc[cfd['Gender'] == gender]))
# print('='*50)
# Out:
# Races in dataset:
# A :  109
# B :  197
# L :  108
# W :  183
# ...
# Genders in dataset:
# F :  307
# M :  290
# ...
